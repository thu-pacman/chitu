# %%
import pandas as pd
data_set = pd.read_parquet(
    "/home/wcz112/UNISERVING/uniserving/metadata-large.parquet", engine="fastparquet"
)
data_set
# Out:
#                                          image_name  \
# 0         3ccdc650-871a-4ad9-9bf2-dc475b83ed32.webp
# 1         1f1fcb70-63a4-40b1-ada9-2c15fb2ca10a.webp
# 2         b0809c6b-cf43-4a82-99f7-6f2947d433fc.webp
# 3         b8cff57e-eb9d-467a-95a1-f6e3b8a38575.webp
# 4         298086cb-1c05-424e-b83b-a6148e8816e2.webp
# ...                                             ...
# 13999995  fb6ced8d-4627-45d2-8710-e5216c0b794e.webp
# 13999996  396e544e-344b-4971-a081-8d58936e17c2.webp
# 13999997  78fa6f35-9468-40ce-95ff-08567b5740d8.webp
# 13999998  383380d9-8768-41d6-8938-d6f67a68b367.webp
# 13999999  3fddd7fd-3b0d-4dd3-9a5d-00724d9f0390.webp
#
#                                                      prompt  part_id  \
# 0         beautiful porcelain ivory fair face woman biom...        1
# 1         complex 3 d render hyper detailed ultra sharp ...        1
# 2         complex 3 d render hyper detailed ultra sharp ...        1
# 3         complex 3 d render hyper detailed ultra sharp ...        1
# 4         complex 3 d render hyper detailed ultra sharp ...        1
# ...                                                     ...      ...
# 13999995  Ibai Berto Romero as Willy Wonka, highly detai...    14000
# 13999996  Ibai Berto Romero as Willy Wonka, highly detai...    14000
# 13999997  Ibai Berto Romero as Willy Wonka, highly detai...    14000
# 13999998  Ibai Berto Romero as Willy Wonka, highly detai...    14000
# 13999999                            paella by studio ghibli    14000
#
#                 seed  step   cfg  sampler  width  height  \
# 0         2625978990    50  21.0        8    512     704
# 1          738462306    50  10.0        8    512     704
# 2         1584972414    50  10.0        8    512     704
# 3         2816373313    50  10.0        8    512     704
# 4         3079866895    50  10.0        8    512     704
# ...              ...   ...   ...      ...    ...     ...
# 13999995  2203538431    50   7.0        8    512     768
# 13999996  1625163903    50   7.0        8    512     768
# 13999997  1987919615    50   7.0        8    512     768
# 13999998  1880276095    50   7.0        8    512     768
# 13999999   857964944    50   7.0        8    512     512
#
#                                                   user_name  \
# 0         01f4e782b48faedf416083b2fbabaca2a45621b15ead23...
# 1         01f4e782b48faedf416083b2fbabaca2a45621b15ead23...
# 2         01f4e782b48faedf416083b2fbabaca2a45621b15ead23...
# 3         01f4e782b48faedf416083b2fbabaca2a45621b15ead23...
# 4         01f4e782b48faedf416083b2fbabaca2a45621b15ead23...
# ...                                                     ...
# 13999995  fcdb3e09f977412c342b6624a19d1295ee1334c153c90a...
# 13999996  fcdb3e09f977412c342b6624a19d1295ee1334c153c90a...
# 13999997  fcdb3e09f977412c342b6624a19d1295ee1334c153c90a...
# 13999998  fcdb3e09f977412c342b6624a19d1295ee1334c153c90a...
# 13999999  fcdb3e09f977412c342b6624a19d1295ee1334c153c90a...
#
#                          timestamp  image_nsfw  prompt_nsfw
# 0        2022-08-20 10:03:00+00:00    0.038466     0.003089
# 1        2022-08-20 10:55:00+00:00    0.187317     0.001722
# 2        2022-08-20 10:55:00+00:00    0.065495     0.001722
# 3        2022-08-20 10:55:00+00:00    0.083114     0.001722
# 4        2022-08-20 10:55:00+00:00    0.148977     0.001722
# ...                            ...         ...          ...
# 13999995 2022-08-07 22:57:00+00:00    0.052320     0.000555
# 13999996 2022-08-07 22:57:00+00:00    0.117837     0.000555
# 13999997 2022-08-07 22:57:00+00:00    0.069527     0.000555
# 13999998 2022-08-07 22:57:00+00:00    0.050364     0.000555
# 13999999 2022-08-07 22:58:00+00:00    0.049369     0.001476
#
# [14000000 rows x 13 columns]

# %%
prompt_all=data_set['prompt']
prompt_unique=prompt_all.unique()
num_all=len(prompt_all)
num_unique=len(prompt_unique)
print(f'{num_all=} {num_unique=} {num_unique/num_all=}')
# Out:
# num_all=14000000 num_unique=1819808 num_unique/num_all=0.12998628571428572

# %%
prompt_all.str.len().describe()
# Out:
# count    1.400000e+07
# mean     1.703520e+02
# std      1.145286e+02
# min      0.000000e+00
# 25%      7.600000e+01
# 50%      1.520000e+02
# 75%      2.490000e+02
# max      1.923000e+03
# Name: prompt, dtype: float64

# %%
prompt_tokens = prompt_all.apply(lambda x: len(x.split()))
prompt_tokens.describe()
# Out:
# count    1.400000e+07
# mean     2.570424e+01
# std      1.664061e+01
# min      0.000000e+00
# 25%      1.200000e+01
# 50%      2.300000e+01
# 75%      3.700000e+01
# max      4.800000e+02
# Name: prompt, dtype: float64

# %%
prompt_unique_tokens = pd.Series(prompt_unique).apply(lambda x: len(x.split()))
prompt_unique_tokens.describe()
# Out:
# count    1.819808e+06
# mean     2.314020e+01
# std      1.589169e+01
# min      0.000000e+00
# 25%      1.000000e+01
# 50%      2.000000e+01
# 75%      3.400000e+01
# max      4.800000e+02
# dtype: float64

# %%
import torch
import os
import sys
import importlib

os.environ["HF_HUB_OFFLINE"] = "1"
# sys.modules.pop('diffusers')
# import diffusers
# importlib.reload(diffusers)
from diffusers import DiffusionPipeline, StableDiffusionXLPipeline
pipe = StableDiffusionXLPipeline.from_pretrained(
    "stabilityai/stable-diffusion-xl-base-1.0",
    torch_dtype=torch.float16,
    variant="fp16",
    use_safetensors=True,
    # low_cpu_mem_usage=False, 
    # device_map=None
)
# Out:
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# == VAE Encoder [
# == VAE Encoder ]
# == VAE Decoder [
# == VAE Decoder ]
# == UNet2D

# %%
pipe.
